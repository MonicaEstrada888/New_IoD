# %% [markdown]
# # Grouping and Sorting

# %%
#This notebook shows Pandas basic applications for grouping and sorting which allow you to scale up the level of data insights. 
#Grouping and sorting is more important when dealing with complex datasets
#The DataFame used is ESGCountry a World Bank dataset related to Environmental, Social, and Corporate Governance data by country
#refers to the three central factors in measuring the sustainability and societal impact of an investment in a company or business.
#The data set has 239 rows and 31 columns

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Groupwise analysis

# %%
Country = pd.read_csv('ESGCountry.csv')
Country
# Out:
#     Country Code    Short Name    Table Name                     Long Name  \
# 0            AFG   Afghanistan   Afghanistan  Islamic State of Afghanistan
# 1            AGO        Angola        Angola   People's Republic of Angola
# 2            ALB       Albania       Albania           Republic of Albania
# 3            AND       Andorra       Andorra       Principality of Andorra
# 4            ARB    Arab World    Arab World                    Arab World
# ..           ...           ...           ...                           ...
# 234          WSM         Samoa         Samoa                         Samoa
# 235          YEM         Yemen   Yemen, Rep.             Republic of Yemen
# 236          ZAF  South Africa  South Africa      Republic of South Africa
# 237          ZMB        Zambia        Zambia            Republic of Zambia
# 238          ZWE      Zimbabwe      Zimbabwe          Republic of Zimbabwe
#
#     2-alpha code       Currency Unit  \
# ...

# %%
Country.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 1          AGO       Angola       Angola   People's Republic of Angola
# 2          ALB      Albania      Albania           Republic of Albania
# 3          AND      Andorra      Andorra       Principality of Andorra
# 4          ARB   Arab World   Arab World                    Arab World
#
#   2-alpha code   Currency Unit  \
# 0           AF  Afghan afghani
# 1           AO  Angolan kwanza
# 2           AL    Albanian lek
# 3           AD            Euro
# 4           1A             NaN
#
#                                        Special Notes                 Region  \
# 0                                                NaN             South Asia
# 1                                                NaN     Sub-Saharan Africa
# 2                                                NaN  Europe & Central Asia
# ...

# %%
#groupby() function: groups information from a column and count how many times each value appeared. 
Country.groupby('Region').Region.count()
# Out:
# Region
# East Asia & Pacific           30
# Europe & Central Asia         52
# Latin America & Caribbean     33
# Middle East & North Africa    20
# North America                  2
# South Asia                     8
# Sub-Saharan Africa            48
# Name: Region, dtype: int64
